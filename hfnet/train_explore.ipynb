# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
#os.chdir("/content/drive/MyDrive/HFNet/hfnet")
os.chdir("/content/drive/Shareddrives/SharedGoogleDrive/hfnet-master")

# %% [markdown]
# # New Section

# %%
# !pip install tensorflow-gpu==1.12 -i https://files.pythonhosted.org/packages/d8/24/52fc6ba729b53ebdb9b4db45e1abae0cd80c93929937c3bcc1435b359732/tensorflow_gpu-1.12.2-cp36-cp36m-manylinux1_x86_64.whl

# %%
#!wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda=9.0.176-1

# %%
# %tensorflow_version 1.x
from tensorflow.python.client import device_lib
import tensorflow as tf
print(tf.__version__)

# %%
# !pip install tensorflow-gpu==1.12

# %%
# !make install  # install Python requirements, setup paths

# %%
#!cp -r /content/drive/Shareddrives/1397241734.HK\(CRN.NGO\)/dataset/DATA_PATH/google_landmarks/content/google_landmarks

# %%
#不跑
# !sudo apt install python3.6
# !update-alternatives --install /usr/local/bin/python3 python3 /usr/bin/python3.6 2
# !update-alternatives --install /usr/local/bin/python3 python3 /usr/bin/python3.7 1
# !python --version

# %%
#!pip install python3.6
# !apt-get install python3-pip
#!python3 -m pip3 python3.6

# %%
# !pip install python3.6
# !python3 -m pip3 python3.6

# %%
#!pip install /download/numpy-1.19.5+mkl-cp36-cp36m-win_amd64.whl

# %%
os.environ['CUDA_VISIBLE_DEVICES']='0' ##要跑
##上面都是配环境，下面是开始预测，就跑那个train distill2的

# %%
# !python3 export_predictions.py hfnet/configs/netvlad_export_distill.yaml global_descriptors --keys global_descriptor \
--as_dataset

# %%
# !python3 export_predictions.py hfnet/configs/superpoint_export_distill.yaml superpoint_predictions --keys local_descriptor_map,dense_scores --as_dataset

# %%
# !python3 export_predictions.py hfnet/configs/netvlad_export_distill.yaml global_descriptors --keys global_descriptor --as_dataset

# %%
# !python3 train.py hfnet/configs/hfnet_train_distill2.yaml hfnet

# %%
# !python3 train.py hfnet/configs/hfnet_train_distill.yaml hfnet

# %%
# !python3 export_model.py config/hfnet_train_distill2.yaml hfnet

# %%
os.environ

# %%
# !nvidia-smi

# %%
# !pip install gast==0.2.2

# %%
# !pip install kapre==0.1.4

# %%
# !python3 export_predictions.py hfnet/configs/netvlad_export_hpatches.yaml hfnet/predictions_hpatches

# %%
tf.__version__
