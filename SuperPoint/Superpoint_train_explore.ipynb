# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/Shareddrives/SharedGoogleDrive/SuperPointDATA/DATA_DIR')
# !pwd
# Out:
# /content/drive/Shareddrives/SharedGoogleDrive/SuperPointDATA/DATA_DIR

# %%
# %cd /content/drive/Shareddrives/SharedGoogleDrive/SuperPoint/
# Out:
# /content/drive/Shareddrives/SharedGoogleDrive/SuperPoint

# %%
# !tar -zxvf ./synthetic_shapes_v6/checkerboard.tar.gz -C
# Out:
# tar (child): ./synthetic_shapes_v6/: Cannot read: Is a directory
# tar (child): At beginning of tape, quitting now
# tar (child): Error is not recoverable: exiting now
#
# gzip: stdin: unexpected end of file
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
#!make install
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
#!bash export TMPDIR=/tmp/
#!bash CUDA_VISIBLE_DEVICES=0
# Out:
#   File "<ipython-input-70-831d66aea9a2>", line 1
#     TMPDIR=/tmp/
#            ^
# SyntaxError: invalid syntax

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cudar-repo-9-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda=9.0.176-1
# Out:
# --2021-06-13 11:00:55--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.16.29
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.16.29|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/9.0/prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb [following]
# --2021-06-13 11:00:56--  https://developer.nvidia.com/compute/cuda/9.0/prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']='0'
os.environ['TMPDIR']='/tmp/'

# %%
# !python experiment.py train superpoint/configs/magic-point_shapes.yaml magic-point_synth
# Out:
# [06/09/2021 00:14:32 INFO] Running command TRAIN
# [06/09/2021 00:14:32 WARNING] From experiment.py:57: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# [06/09/2021 00:14:32 INFO] Number of GPUs detected: 1
# [06/09/2021 00:14:37 INFO] NumExpr defaulting to 2 threads.
# [06/09/2021 00:14:38 WARNING] From /content/drive/Shareddrives/SharedGoogleDrive/SuperPoint/superpoint/datasets/synthetic_shapes.py:129: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# [06/09/2021 00:14:38 INFO] Extracting archive for primitive draw_lines.
# [06/09/2021 00:14:45 INFO] Extracting archive for primitive draw_polygon.
# [06/09/2021 00:14:53 INFO] Extracting archive for primitive draw_multiple_polygons.
# [06/09/2021 00:15:01 INFO] Extracting archive for primitive draw_ellipses.
# [06/09/2021 00:15:07 INFO] Extracting archive for primitive draw_star.
# ...

# %%
# !python export_detections.py configs/magic-point_coco_export.yaml magic-point_synth --pred_only --batch_size=5 --export_name=magic-point_coco-export1

# %%
# !python experiment.py train configs/magic-point_coco_train.yaml magic-point_coco

# %%
# !python export_detections_repeatability.py configs/magic-point_repeatability.yaml magic-point_coco --export_name=magic-point_hpatches-repeatability-v

# %%
# !python experiment.py train configs/superpoint_coco.yaml superpoint_coco

# %%
# !python export_descriptors.py configs/superpoint_hpatches.yaml superpoint_coco --export_name=superpoint_hpatches-v

# %%
import os
# %cd  /content/drive/Shareddrives/SharedGoogleDrive/SuperPointDATA/DATA_DIR/COCO/
# Out:
# /content/drive/Shareddrives/SharedGoogleDrive/SuperPointDATA/DATA_DIR/COCO

# %%
f_names=os.listdir()

# %%
# !nvidia-smi
# Out:
# Sun Jun 13 11:03:36 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    35W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/Shareddrives/SharedGoogleDrive/SuperPoint
# !python3 export_detections.py superpoint/configs/magic-point_coco_export.yaml magic-point_synth --pred_only --batch_size=5 --export_name=magic-point_coco-export1
